# %% [markdown]
# <a href="https://colab.research.google.com/github/Taiba053/Wine_Prediction/blob/main/ybipro1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Title:
# Wine Quality Prediction Using Support Vector Machi

# %% [markdown]
# Objective:
#
# Developing a Machine Learning Model to predict the quality of white wine utilizing SVM, focusing on data preprocessing, model training, evaluation, and visualization for effective quality assessment.
#
# Optimizing the classification of white Wine Quality using Support Vector Machine (SVM) algorithm, ensuring robust evaluation and visual representation of the model's performance through accuracy, confusion matrix, and classification report.

# %% [markdown]
# Data source:
#
# Dataset hosted by GitHub

# %%
#import library
import pandas as pd
import numpy as np

# %%
#import Data
df=pd.read_csv('/content/WhiteWineQuality.csv',delimiter=';')
df.head()
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
#Target Variable(y) and Feature Variable(x)
y=df['quality']
x=df.drop(['quality'],axis=1)

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,stratify=y, random_state=2529)

# %%
#Model fit
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
#Make Prediction
y_pred = svc.predict(x_test)

# %%
#Model Evalution
from sklearn.metrics import confusion_matrix, classification_report
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)

# Plot Confusion Matrix
plt.figure(figsize=(10,7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4530612244897959
# Confusion Matrix:
# ...

# %% [markdown]
# Explanation:
#
#  This Model can predict the quality of wine using a Support Vector Machine (SVM) model. First things, we import some essential libraries like pandas and numpy for data manipulation, and sklearn for all our machine learning needs. Then, we load up the dataset from a CSV file, using a semicolon as the delimiter. We also display some basic info about the dataset, like the first few rows, column names, and summary statistics.
#
#  Now,check if there are any missing values in the dataset,if no then We separate the target variable, which is the 'quality', from the feature variables, which are all the other columns. This helps us train the model better.
#
#  To make sure our features are comparable, we standardize the feature variables. This means we give them a mean of 0 and a standard deviation of 1.  we create and train our SVM model using a linear kernel.
#
#   The model is trained, we can use it to predict the quality of wine in our test set. Evaluating Model, We've got some metrics, like accuracy, confusion matrix, and classification report. Accuracy gives us a simple measure of how well the model performed overall. The confusion matrix and classification report give us more detailed insights into how the model classified different quality levels
